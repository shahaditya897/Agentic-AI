# %%
# Import Libraries
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# Sentences
documents = [
    "Cats are friendly animals.",
    "Dogs are loyal pets.",
    "Birds can fly in the sky.",
    "Fish live in water."
]

# Create TF-IDF Vectorizer
vectorizer = TfidfVectorizer()

# Convert Text into TF-IDF Matrix
tfidf_matrix = vectorizer.fit_transform(documents)

# Display Sparse Matrix
print("Sparse Matrix\n")
print(tfidf_matrix)

# Convert Matrix into DataFrame
table = pd.DataFrame(
    tfidf_matrix.toarray(),
    columns=vectorizer.get_feature_names_out()
)

print("\nTF-IDF Table\n")

# Display Table (Google Colab/Jupyter)
table
# Out:
# Sparse Matrix
#
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 18 stored elements and shape (4, 16)>
#   Coords	Values
#   (0, 4)	0.5254727492640658
#   (0, 1)	0.41428875116588965
#   (0, 8)	0.5254727492640658
#   (0, 0)	0.5254727492640658
#   (1, 1)	0.41428875116588965
#   (1, 5)	0.5254727492640658
#   (1, 11)	0.5254727492640658
#   (1, 12)	0.5254727492640658
#   (2, 2)	0.4217647821447532
#   (2, 3)	0.4217647821447532
#   (2, 7)	0.4217647821447532
#   (2, 9)	0.3325241986862672
#   (2, 14)	0.4217647821447532
#   (2, 13)	0.4217647821447532
#   (3, 9)	0.41428875116588965
#   (3, 6)	0.5254727492640658
#   (3, 10)	0.5254727492640658
#   (3, 15)	0.5254727492640658
#
# TF-IDF Table
#     animals       are     birds       can      cats      dogs      fish  \
# 0  0.525473  0.414289  0.000000  0.000000  0.525473  0.000000  0.000000
# 1  0.000000  0.414289  0.000000  0.000000  0.000000  0.525473  0.000000
# 2  0.000000  0.000000  0.421765  0.421765  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.525473
#
#         fly  friendly        in      live     loyal      pets       sky  \
# 0  0.000000  0.525473  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.525473  0.525473  0.000000
# 2  0.421765  0.000000  0.332524  0.000000  0.000000  0.000000  0.421765
# 3  0.000000  0.000000  0.414289  0.525473  0.000000  0.000000  0.000000
#
#         the     water
# 0  0.000000  0.000000
# 1  0.000000  0.000000
# 2  0.421765  0.000000
# 3  0.000000  0.525473
